# %%
#importing necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#loading dataset
df = pd.read_csv('flight.csv')
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 #loading dataset
# ----> 2 df = pd.read_csv('flight.csv')
#       3 df
#
# File ~\anaconda3\envs\learn-env\lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File ~\anaconda3\envs\learn-env\lib\site-packages\pandas\io\parsers\readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File ~\anaconda3\envs\learn-env\lib\site-packages\pandas\io\parsers\readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File ~\anaconda3\envs\learn-env\lib\site-packages\pandas\io\parsers\readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File ~\anaconda3\envs\learn-env\lib\site-packages\pandas\io\common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'flight.csv'

# %%
#Sorting duplicates
df[df.duplicated(keep=False)].sort_values(by='type')
df

# %%
#Dropping duplicates
df = df.drop_duplicates()
df

# %%
#Remove unnecessary index column 'Unnamed: 0'
if 'Unnamed: 0' in df.columns:
    df = df.drop(columns=['Unnamed: 0'])
df

# %%
# Remove rows where 'acc.date' is empty after cleaning
df = df.copy()
#Ensuring the date is in a string
df['acc.date'] = df['acc.date'].astype(str)
#Removing 'xx' and ' ' and replacing with False
df['acc.date'] = df['acc.date'].str.replace('xx', '', regex=False)
#Removing unk.date, and replacing with false
df['acc.date'] = df['acc.date'].str.replace('unk. date', '', regex=False)
# Removing spaces in our string
df['acc.date'] = df['acc.date'].str.strip()
# Convert to datetime
df['acc.date'] = pd.to_datetime(df['acc.date'], errors='coerce')
#Converting acc.date from object to datetime
# Drop rows where conversion failed (NaT)
df = df.dropna(subset=['acc.date'])
df['acc.date']

# %%
# Extract year from 'acc.date' and create a new column
df['year'] = df['acc.date'].dt.year
df

# %%
# Selecting relevant columns

rel_columns = ['acc.date','type','operator','fat','location','dmg']
df = df[rel_columns]
df.head()

# %%
#naming the columns properly
df.columns = ['acc.date', 'aircraft_type', 'operator', 'location','fatalities', 'damage']
df.head()

# %%
#Remove spaces
df['aircraft_type'] = df['aircraft_type'].str.strip() 
# Standardize Capitalization
df['aircraft_type'] = df['aircraft_type'].str.title() 
df['aircraft_type']

# %%
# Cleaning Fatalities column
#Converting from a string to numeric, filling missing values and making it an integer
df['fatalities'] = pd.to_numeric(df['fatalities'], errors='coerce').fillna(0).astype(int)
df['fatalities']

# %%
 #Strip whitespace and lowercase
df['damage'] = df['damage'].str.strip().str.lower()

# Replace shorthand codes with full,standardized labels
df['damage'] = df['damage'].replace({'sub': 'Substantial','w/o': 'Written Off','non': 'None','min': 'Minor','mis':'Missing','unk':'Unknown'})

#Fill any missing values
df['damage'] = df['damage'].fillna('Unknown')
df['damage']

# %%
Total_Flight = (
    df
    .groupby('aircraft_type', as_index=False)
    .agg(
        dmg=('aircraft_type', 'count'),
        fat=('fatalities', 'sum'),
    )
    .sort_values('dmg', ascending=False)
)
Total_Flight= Total_Flight.head(5)
Total_Flight

# %%
top5_aircraft = Total_Flight.head(5)
top5_aircraft

# %%
df.to_csv("flight_clean.csv", index=False)

# %%
Total_Flight.to_csv("Total_Flight.csv", index=False)
