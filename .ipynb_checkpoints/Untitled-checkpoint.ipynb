# %%
#importing necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#loading dataset
df = pd.read_csv('flight.csv')
df
# Out:
#       Unnamed: 0        acc.date                                 type  \
# 0              0      3 Jan 2022  British Aerospace 4121 Jetstream 41
# 1              1      4 Jan 2022  British Aerospace 3101 Jetstream 31
# 2              2      5 Jan 2022                       Boeing 737-4H6
# 3              3      8 Jan 2022                  Tupolev Tu-204-100C
# 4              4     12 Jan 2022        Beechcraft 200 Super King Air
# ...          ...             ...                                  ...
# 2495        1245     20 Dec 2018                Cessna 560 Citation V
# 2496        1246     22 Dec 2018              PZL-Mielec M28 Skytruck
# 2497        1247     24 Dec 2018                       Antonov An-26B
# 2498        1248     31 Dec 2018                  Boeing 757-2B7 (WL)
# 2499        1249  unk. date 2018               Rockwell Sabreliner 80
#
#             reg                                           operator fat  \
# 0        ZS-NRJ                                         SA Airlink   0
# 1        HR-AYY      LANHSA - Línea Aérea Nacional de Honduras S.A   0
# 2        EP-CAP                                   Caspian Airlines   0
# 3      RA-64032                           Cainiao, opb Aviastar-TU   0
# 4           NaN                                            private   0
# ...         ...                                                ...  ..
# 2495     N188CW                                 Chen Aircrafts LLC   4
# 2496  GNB-96107   Guardia Nacional Bolivariana de Venezuela - GNBV   0
# 2497     9T-TAB  Air Force of the Democratic Republic of the Congo   0
# 2498     N938UW                                  American Airlines   0
# 2499     N337KL                                            private   0
#
#                                                location  dmg
# 0                             near Venetia Mine Airport  sub
# 1     Roatán-Juan Manuel Gálvez International Airpor...  sub
# 2                 Isfahan-Shahid Beheshti Airport (IFN)  sub
# 3         Hangzhou Xiaoshan International Airport (HGH)  w/o
# 4        Machakilha, Toledo District, Grahem Creek area  w/o
# ...                                                 ...  ...
# 2495  2 km NE of Atlanta-Fulton County Airport, GA (...  w/o
# 2496                             Kamarata Airport (KTV)  sub
# 2497                                 Beni Airport (BNC)  w/o
# 2498  Charlotte-Douglas International Airport, NC (C...  sub
# 2499                           Eugene Airport, OR (EUG)  sub
#
# [2500 rows x 8 columns]

# %%
#Sorting duplicates
df[df.duplicated(keep=False)].sort_values(by='type')
df
# Out:
#       Unnamed: 0        acc.date                                 type  \
# 0              0      3 Jan 2022  British Aerospace 4121 Jetstream 41
# 1              1      4 Jan 2022  British Aerospace 3101 Jetstream 31
# 2              2      5 Jan 2022                       Boeing 737-4H6
# 3              3      8 Jan 2022                  Tupolev Tu-204-100C
# 4              4     12 Jan 2022        Beechcraft 200 Super King Air
# ...          ...             ...                                  ...
# 2495        1245     20 Dec 2018                Cessna 560 Citation V
# 2496        1246     22 Dec 2018              PZL-Mielec M28 Skytruck
# 2497        1247     24 Dec 2018                       Antonov An-26B
# 2498        1248     31 Dec 2018                  Boeing 757-2B7 (WL)
# 2499        1249  unk. date 2018               Rockwell Sabreliner 80
#
#             reg                                           operator fat  \
# 0        ZS-NRJ                                         SA Airlink   0
# 1        HR-AYY      LANHSA - Línea Aérea Nacional de Honduras S.A   0
# 2        EP-CAP                                   Caspian Airlines   0
# 3      RA-64032                           Cainiao, opb Aviastar-TU   0
# 4           NaN                                            private   0
# ...         ...                                                ...  ..
# 2495     N188CW                                 Chen Aircrafts LLC   4
# 2496  GNB-96107   Guardia Nacional Bolivariana de Venezuela - GNBV   0
# 2497     9T-TAB  Air Force of the Democratic Republic of the Congo   0
# 2498     N938UW                                  American Airlines   0
# 2499     N337KL                                            private   0
#
#                                                location  dmg
# 0                             near Venetia Mine Airport  sub
# 1     Roatán-Juan Manuel Gálvez International Airpor...  sub
# 2                 Isfahan-Shahid Beheshti Airport (IFN)  sub
# 3         Hangzhou Xiaoshan International Airport (HGH)  w/o
# 4        Machakilha, Toledo District, Grahem Creek area  w/o
# ...                                                 ...  ...
# 2495  2 km NE of Atlanta-Fulton County Airport, GA (...  w/o
# 2496                             Kamarata Airport (KTV)  sub
# 2497                                 Beni Airport (BNC)  w/o
# 2498  Charlotte-Douglas International Airport, NC (C...  sub
# 2499                           Eugene Airport, OR (EUG)  sub
#
# [2500 rows x 8 columns]

# %%
#Dropping duplicates
df = df.drop_duplicates()
df
# Out:
#       Unnamed: 0        acc.date                                 type  \
# 0              0      3 Jan 2022  British Aerospace 4121 Jetstream 41
# 1              1      4 Jan 2022  British Aerospace 3101 Jetstream 31
# 2              2      5 Jan 2022                       Boeing 737-4H6
# 3              3      8 Jan 2022                  Tupolev Tu-204-100C
# 4              4     12 Jan 2022        Beechcraft 200 Super King Air
# ...          ...             ...                                  ...
# 1245        1245     20 Dec 2018                Cessna 560 Citation V
# 1246        1246     22 Dec 2018              PZL-Mielec M28 Skytruck
# 1247        1247     24 Dec 2018                       Antonov An-26B
# 1248        1248     31 Dec 2018                  Boeing 757-2B7 (WL)
# 1249        1249  unk. date 2018               Rockwell Sabreliner 80
#
#             reg                                           operator fat  \
# 0        ZS-NRJ                                         SA Airlink   0
# 1        HR-AYY      LANHSA - Línea Aérea Nacional de Honduras S.A   0
# 2        EP-CAP                                   Caspian Airlines   0
# 3      RA-64032                           Cainiao, opb Aviastar-TU   0
# 4           NaN                                            private   0
# ...         ...                                                ...  ..
# 1245     N188CW                                 Chen Aircrafts LLC   4
# 1246  GNB-96107   Guardia Nacional Bolivariana de Venezuela - GNBV   0
# 1247     9T-TAB  Air Force of the Democratic Republic of the Congo   0
# 1248     N938UW                                  American Airlines   0
# 1249     N337KL                                            private   0
#
#                                                location  dmg
# 0                             near Venetia Mine Airport  sub
# 1     Roatán-Juan Manuel Gálvez International Airpor...  sub
# 2                 Isfahan-Shahid Beheshti Airport (IFN)  sub
# 3         Hangzhou Xiaoshan International Airport (HGH)  w/o
# 4        Machakilha, Toledo District, Grahem Creek area  w/o
# ...                                                 ...  ...
# 1245  2 km NE of Atlanta-Fulton County Airport, GA (...  w/o
# 1246                             Kamarata Airport (KTV)  sub
# 1247                                 Beni Airport (BNC)  w/o
# 1248  Charlotte-Douglas International Airport, NC (C...  sub
# 1249                           Eugene Airport, OR (EUG)  sub
#
# [1250 rows x 8 columns]

# %%
#Remove unnecessary index column 'Unnamed: 0'
if 'Unnamed: 0' in df.columns:
    df = df.drop(columns=['Unnamed: 0'])
df
# Out:
#             acc.date                                 type        reg  \
# 0         3 Jan 2022  British Aerospace 4121 Jetstream 41     ZS-NRJ
# 1         4 Jan 2022  British Aerospace 3101 Jetstream 31     HR-AYY
# 2         5 Jan 2022                       Boeing 737-4H6     EP-CAP
# 3         8 Jan 2022                  Tupolev Tu-204-100C   RA-64032
# 4        12 Jan 2022        Beechcraft 200 Super King Air        NaN
# ...              ...                                  ...        ...
# 1245     20 Dec 2018                Cessna 560 Citation V     N188CW
# 1246     22 Dec 2018              PZL-Mielec M28 Skytruck  GNB-96107
# 1247     24 Dec 2018                       Antonov An-26B     9T-TAB
# 1248     31 Dec 2018                  Boeing 757-2B7 (WL)     N938UW
# 1249  unk. date 2018               Rockwell Sabreliner 80     N337KL
#
#                                                operator fat  \
# 0                                            SA Airlink   0
# 1         LANHSA - Línea Aérea Nacional de Honduras S.A   0
# 2                                      Caspian Airlines   0
# 3                              Cainiao, opb Aviastar-TU   0
# 4                                               private   0
# ...                                                 ...  ..
# 1245                                 Chen Aircrafts LLC   4
# 1246   Guardia Nacional Bolivariana de Venezuela - GNBV   0
# 1247  Air Force of the Democratic Republic of the Congo   0
# 1248                                  American Airlines   0
# 1249                                            private   0
#
#                                                location  dmg
# 0                             near Venetia Mine Airport  sub
# 1     Roatán-Juan Manuel Gálvez International Airpor...  sub
# 2                 Isfahan-Shahid Beheshti Airport (IFN)  sub
# 3         Hangzhou Xiaoshan International Airport (HGH)  w/o
# 4        Machakilha, Toledo District, Grahem Creek area  w/o
# ...                                                 ...  ...
# 1245  2 km NE of Atlanta-Fulton County Airport, GA (...  w/o
# 1246                             Kamarata Airport (KTV)  sub
# 1247                                 Beni Airport (BNC)  w/o
# 1248  Charlotte-Douglas International Airport, NC (C...  sub
# 1249                           Eugene Airport, OR (EUG)  sub
#
# [1250 rows x 7 columns]

# %%
# Remove rows where 'acc.date' is empty after cleaning
df = df.copy()
#Ensuring the date is in a string
df['acc.date'] = df['acc.date'].astype(str)
#Removing 'xx' and ' ' and replacing with False
df['acc.date'] = df['acc.date'].str.replace('xx', '', regex=False)
#Removing unk.date, and replacing with false
df['acc.date'] = df['acc.date'].str.replace('unk. date', '', regex=False)
# Removing spaces in our string
df['acc.date'] = df['acc.date'].str.strip()
# Convert to datetime
df['acc.date'] = pd.to_datetime(df['acc.date'], errors='coerce')
#Converting acc.date from object to datetime
# Drop rows where conversion failed (NaT)
df = df.dropna(subset=['acc.date'])
df['acc.date']
# Out:
# 0      2022-01-03
# 1      2022-01-04
# 2      2022-01-05
# 3      2022-01-08
# 4      2022-01-12
#           ...
# 1244   2018-12-20
# 1245   2018-12-20
# 1246   2018-12-22
# 1247   2018-12-24
# 1248   2018-12-31
# Name: acc.date, Length: 1247, dtype: datetime64[ns]

# %%
# Extract year from 'acc.date' and create a new column
df['year'] = df['acc.date'].dt.year
df
# Out:
#        acc.date                                 type        reg  \
# 0    2022-01-03  British Aerospace 4121 Jetstream 41     ZS-NRJ
# 1    2022-01-04  British Aerospace 3101 Jetstream 31     HR-AYY
# 2    2022-01-05                       Boeing 737-4H6     EP-CAP
# 3    2022-01-08                  Tupolev Tu-204-100C   RA-64032
# 4    2022-01-12        Beechcraft 200 Super King Air        NaN
# ...         ...                                  ...        ...
# 1244 2018-12-20                       Antonov An-26B     9S-AGB
# 1245 2018-12-20                Cessna 560 Citation V     N188CW
# 1246 2018-12-22              PZL-Mielec M28 Skytruck  GNB-96107
# 1247 2018-12-24                       Antonov An-26B     9T-TAB
# 1248 2018-12-31                  Boeing 757-2B7 (WL)     N938UW
#
#                                                operator fat  \
# 0                                            SA Airlink   0
# 1         LANHSA - Línea Aérea Nacional de Honduras S.A   0
# 2                                      Caspian Airlines   0
# 3                              Cainiao, opb Aviastar-TU   0
# 4                                               private   0
# ...                                                 ...  ..
# 1244                                             Gomair   7
# 1245                                 Chen Aircrafts LLC   4
# 1246   Guardia Nacional Bolivariana de Venezuela - GNBV   0
# 1247  Air Force of the Democratic Republic of the Congo   0
# 1248                                  American Airlines   0
#
#                                                location  dmg  year
# 0                             near Venetia Mine Airport  sub  2022
# 1     Roatán-Juan Manuel Gálvez International Airpor...  sub  2022
# 2                 Isfahan-Shahid Beheshti Airport (IFN)  sub  2022
# 3         Hangzhou Xiaoshan International Airport (HGH)  w/o  2022
# 4        Machakilha, Toledo District, Grahem Creek area  w/o  2022
# ...                                                 ...  ...   ...
# 1244       ca 37 km from Kinshasa-N'Djili Airport (FIH)  w/o  2018
# 1245  2 km NE of Atlanta-Fulton County Airport, GA (...  w/o  2018
# 1246                             Kamarata Airport (KTV)  sub  2018
# 1247                                 Beni Airport (BNC)  w/o  2018
# 1248  Charlotte-Douglas International Airport, NC (C...  sub  2018
#
# [1247 rows x 8 columns]

# %%
aircraft_summary = (
    flight_data
    .groupby('type', as_index=False)
    .agg(
        total_accidents=('type', 'count'),
        total_fatalities=('fatality', 'sum')
    )
    .sort_values('total_accidents', ascending=False)
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 aircraft_summary = (
# ----> 2     flight_data
#       3     .groupby('type', as_index=False)
#       4     .agg(
#       5         total_accidents=('type', 'count'),
#       6         total_fatalities=('fatality', 'sum')
#       7     )
#       8     .sort_values('total_accidents', ascending=False)
#       9 )
#
# NameError: name 'flight_data' is not defined
